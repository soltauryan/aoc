# %%
import aocd

# %%
data = aocd.get_data(day=1, year=2016)
data_orig = data

# %%
data = data.split(", ")
data

# %%
type(data)
# Out:
# str

# %%
test = "R2, L3".split(", ")
test
# Out:
# ['R2', 'L3']

# %%
turn_dict = {
    "N": ("W", "E"),
    "E": ("N", "S"),
    "S": ("E", "W"),
    "W": ("S", "N"),
}

coord_delta_dict = {
    "N": (0, 1),
    "E": (1, 0),
    "S": (0, -1),
    "W": (-1, 0),
}

def turn(dir, turn):
    if turn == "L":
        return turn_dict[dir][0]
    else:
        return turn_dict[dir][1]

def main(data):
    coord = (0, 0)
    dir = "N"
# Out:
# 'E'
