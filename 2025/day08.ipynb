def return_distance_dict(boxes):
    dist_dict = {}

    for i in range(len(boxes)):
        for j in range(i+1, len(boxes)):
            c1, c2 = boxes[i], boxes[j]
            dist_dict[str([c1, c2])] = euclid_distance(c1, c2)

    dist_dict = dict(sorted(dist_dict.items(), key=lambda item: item[1]))

    return dist_dict

def return_min_circuit_len(circuits):
    return min([len(c) for c in circuits])

# def p1(data):
#     boxes = ingest(data)
#     dist_dict = return_distance_dict(boxes)
#     dist_list = [list(eval(l)) for l in list(dist_dict.keys())]
#     circuit_list = [[box] for box in boxes]

#     i = 0
#     limit = 10
#     for j in range(0, limit):
#         c1, c2 = dist_list[j][0], dist_list[j][1]
#         for cir in circuit_list:
#             if c1 in cir:
#                 cir.append(c2)
#             if c2 == cir:
#                 circuit_list.remove(c2)

#     print(len(circuit_list))
#     return dist_dict, circuit_list

def p1(data):
    boxes = ingest(data)
    n = len(boxes)

    distances = []
    for i in range(n):
        for j in range(i+1, n):
            d = euclid_distance(boxes[i], boxes[j])
            distances.append((d, i, j))

    distances.sort()

    parent = list(range(n))

    def find(i):
        if parent[i] == i:
            return i
        parent[i] = find(parent[i])
        return parent[i]
    
    def union(i, j):
        root_i = find(i)
        root_j = find(j)
        if root_i != root_j:
            parent[root_i] = root_j 

    limit = 1000
    for k in range(limit):
        _, idx1, idx2 = distances[k]
        union(idx1, idx2)

    circuit_leaders = [find(i) for i in range(n)]
    counts = Counter(circuit_leaders)
    print(f"counts len: {len(counts)}")
    sizes = sorted(counts.values(), reverse=True)
    print(sizes)

    if len(sizes) >= 3:
        return sizes[0] * sizes[1] * sizes[2]
    else:
        product = 1
        for s in sizes:
            product *= s
        return product


def p2(data):
    boxes = ingest(data)
    n = len(boxes)

    distances = []
    for i in range(n):
        for j in range(i+1, n):
            d = euclid_distance(boxes[i], boxes[j])
            distances.append((d, i, j))

    distances.sort()

    parent = list(range(n))

    def find(i):
        if parent[i] == i:
            return i
        parent[i] = find(parent[i])
        return parent[i]
    
    def union(i, j):
        root_i = find(i)
        root_j = find(j)
        if root_i != root_j:
            parent[root_i] = root_j 

    limit = len(distances)
    for k in range(limit):
        _, idx1, idx2 = distances[k]
        union(idx1, idx2)
        circuit_leaders = [find(i) for i in range(n)]
        counts = Counter(circuit_leaders)
        if len(counts) == 1:
            return boxes[idx1], boxes[idx2]

    # circuit_leaders = [find(i) for i in range(n)]
    # counts = Counter(circuit_leaders)
    # print(f"counts len: {len(counts)}")
    # sizes = sorted(counts.values(), reverse=True)
    # print(sizes)

    # if len(sizes) >= 3:
    #     return sizes[0] * sizes[1] * sizes[2]
    # else:
    #     product = 1
    #     for s in sizes:
    #         product *= s
    #     return product


c1, c2 = p2(data)
print(c1, c2)
print(c1[0] * c2[0])
# Out:
# [90968, 13304, 86478] [99700, 4569, 92874]
# 9069509600

# %%
min([len(c) for c in t])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 min([len(c) for c in t])
#
# NameError: name 't' is not defined

# %%
str([1, 2, 3]).split(", ")
# Out:
# ['[1', '2', '3]']

# %%
list(eval("[[1, 2, 3], [4,5,6]]"))
# Out:
# [[1, 2, 3], [4, 5, 6]]
